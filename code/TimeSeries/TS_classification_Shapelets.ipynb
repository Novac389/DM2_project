# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_val_score 

from sklearn.model_selection import train_test_split, cross_val_score 
from sklearn.metrics import accuracy_score, f1_score, classification_report
import gc

from tslearn.piecewise import PiecewiseAggregateApproximation
from IPython.display import Audio
from tqdm.notebook import tqdm

from keras.optimizers import Adagrad
from tslearn.shapelets import ShapeletModel
from tslearn.shapelets import grabocka_params_to_shapelet_size_dict

import warnings
warnings.filterwarnings('ignore')

# %%
X_train = np.load("../DATASETS/TimeSeriesTrimmed/X_train.npy")
y_train = pd.read_csv("../DATASETS/TimeSeriesTrimmed/y_train.csv")

X_test = np.load("../DATASETS/TimeSeriesTrimmed/X_test.npy")
y_test = pd.read_csv("../DATASETS/TimeSeriesTrimmed/y_test.csv")

# np.nan_to_num(X_train,copy=False)
# np.nan_to_num(X_test,copy=False)
print(X_train.shape,X_test.shape)
# Out:
# (1828, 243200) (624, 243200)

# %% [markdown]
# ## Random sampling

# %%
sample_idxs_train=y_train.groupby('emotion')['filename'].apply(lambda s: s.sample(25)).index.get_level_values(1)
sample_idxs_test=y_test.groupby('emotion')['filename'].apply(lambda s: s.sample(10)).index.get_level_values(1)

# %%
X_train=X_train[sample_idxs_train]
y_train=y_train.iloc[sample_idxs_train]

X_test=X_test[sample_idxs_test]
y_test=y_test.iloc[sample_idxs_test]

print(X_train.shape,X_test.shape)
# Out:
# (200, 243200) (80, 243200)

# %% [markdown]
# ## Appro

# %%
n_paa_segments = 2000
paa = PiecewiseAggregateApproximation(n_segments=n_paa_segments)

X_train_paa = list()
for ts in tqdm(X_train):
    ts = ts[~np.isnan(ts)].reshape(1,-1)
    ts_paa = paa.fit_transform(ts).squeeze()
    X_train_paa.append(ts_paa)
    
X_test_paa = list()
for ts in tqdm(X_test):
    ts = ts[~np.isnan(ts)].reshape(1,-1)
    ts_paa = paa.fit_transform(ts).squeeze()
    X_test_paa.append(ts_paa)
    
X_train=np.array(X_train_paa)
X_test=np.array(X_test_paa)
del X_train_paa,X_test_paa
gc.collect()
# Out:
#   0%|          | 0/1828 [00:00<?, ?it/s]
#   0%|          | 0/624 [00:00<?, ?it/s]
# 68

# %%
emotion_mapper = {"neutral":0, "calm":1, "happy":2, "sad":3, "angry":4, "fearful":5, "disgust":6, "surprised":7}
y_train = y_train["emotion"].replace(emotion_mapper)
y_test = y_test["emotion"].replace(emotion_mapper)

# %% [markdown]
# # Shaplet Classifiers

# %% [markdown]
# ## Brute Force Approach

# %%
from pyts.transformation import ShapeletTransform

# %%
# Shapelet transformation
st = ShapeletTransform(n_shapelets=6,
                        window_sizes=[100],
                        sort=True,
                        n_jobs=-1,
                        verbose=50)
X_new = st.fit_transform(X_train, y_train)
X_test_new = st.transform(X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 174 out of 200 | elapsed: 10.4min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done 179 out of 200 | elapsed: 11.1min remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done 184 out of 200 | elapsed: 11.2min remaining:   58.4s
# [Parallel(n_jobs=-1)]: Done 189 out of 200 | elapsed: 11.3min remaining:   39.3s
# [Parallel(n_jobs=-1)]: Done 194 out of 200 | elapsed: 11.8min remaining:   21.8s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed: 11.9min finished

# %%
plt.figure(figsize=(12, 4))
for i, index in enumerate(st.indices_[:3]):
    idx, start, end = index
    plt.plot(X_train[idx], color='C{}'.format(i),alpha=0.1)
    plt.plot(np.arange(start, end), X_train[idx, start:end],lw=1.5, color='C{}'.format(i),label='Sample {}'.format(idx))

plt.xlabel('Time', fontsize=12)
plt.title('The three most discriminative shapelets', fontsize=14)
plt.legend(loc='best', fontsize=8)
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_new, y_train)

y_pred = clf.predict(X_test_new)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.1875
# F1-score [0.23529412 0.5        0.09090909 0.21052632 0.31578947 0.14285714
#  0.1        0.        ]
#               precision    recall  f1-score   support
#
#            0       0.29      0.20      0.24        10
#            1       0.67      0.40      0.50        10
#            2       0.08      0.10      0.09        10
#            3       0.22      0.20      0.21        10
#            4       0.33      0.30      0.32        10
#            5       0.11      0.20      0.14        10
#            6       0.10      0.10      0.10        10
#            7       0.00      0.00      0.00        10
#
#     accuracy                           0.19        80
#    macro avg       0.23      0.19      0.20        80
# weighted avg       0.23      0.19      0.20        80

# %% [raw]
# Accuracy 0.1875
# F1-score [0.23529412 0.5        0.09090909 0.21052632 0.31578947 0.14285714
#  0.1        0.        ]
#               precision    recall  f1-score   support
#
#            0       0.29      0.20      0.24        10
#            1       0.67      0.40      0.50        10
#            2       0.08      0.10      0.09        10
#            3       0.22      0.20      0.21        10
#            4       0.33      0.30      0.32        10
#            5       0.11      0.20      0.14        10
#            6       0.10      0.10      0.10        10
#            7       0.00      0.00      0.00        10
#
#     accuracy                           0.19        80
#    macro avg       0.23      0.19      0.20        80
# weighted avg       0.23      0.19      0.20        80

# %% [markdown]
# ## Learning-based Approach

# %%
from keras.optimizers import Adagrad
from tslearn.shapelets import ShapeletModel
from tslearn.shapelets import grabocka_params_to_shapelet_size_dict

# %%
n_ts, ts_sz = X_train.shape
n_classes = len(set(y_train))

# Set the number of shapelets per size as done in the original paper
shapelet_sizes = grabocka_params_to_shapelet_size_dict(n_ts=n_ts,
                                                       ts_sz=ts_sz,
                                                       n_classes=n_classes,
                                                       l=0.1,
                                                       r=1)

print('n_ts', n_ts)
print('ts_sz', ts_sz)
print('n_classes', n_classes)
print('shapelet_sizes', shapelet_sizes)
# Out:
# n_ts 1828
# ts_sz 2000
# n_classes 8
# shapelet_sizes {200: 7}

# %%
# Define the model using parameters provided by the authors (except that we use
# fewer iterations here)
shp_clf = ShapeletModel(n_shapelets_per_size=shapelet_sizes,
                        optimizer="sgd",
                        weight_regularizer=.01,
                        max_iter=10,
                        verbose=1,)

# %%
shp_clf.fit(X_train, y_train)
y_pred = shp_clf.predict(X_test)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 2s 136ms/step - loss: 2.1554 - categorical_accuracy: 0.1532 - categorical_crossentropy: 2.0785
# Epoch 2/10
# 8/8 [==============================] - 1s 131ms/step - loss: 2.1544 - categorical_accuracy: 0.1532 - categorical_crossentropy: 2.0778
# Epoch 3/10
# 8/8 [==============================] - 1s 139ms/step - loss: 2.1534 - categorical_accuracy: 0.1532 - categorical_crossentropy: 2.0770
# Epoch 4/10
# 8/8 [==============================] - 1s 142ms/step - loss: 2.1525 - categorical_accuracy: 0.1532 - categorical_crossentropy: 2.0763
# Epoch 5/10
# 8/8 [==============================] - 1s 141ms/step - loss: 2.1514 - categorical_accuracy: 0.1532 - categorical_crossentropy: 2.0755
# Epoch 6/10
# 8/8 [==============================] - 1s 141ms/step - loss: 2.1504 - categorical_accuracy: 0.1532 - categorical_crossentropy: 2.0747
# Epoch 7/10
# 8/8 [==============================] - 1s 143ms/step - loss: 2.1494 - categorical_accuracy: 0.1532 - categorical_crossentropy: 2.0740
# Epoch 8/10
# 8/8 [==============================] - 1s 139ms/step - loss: 2.1484 - categorical_accuracy: 0.1532 - categorical_crossentropy: 2.0732
# Epoch 9/10
# 8/8 [==============================] - 1s 139ms/step - loss: 2.1474 - categorical_accuracy: 0.1532 - categorical_crossentropy: 2.0725
# Epoch 10/10
# 8/8 [==============================] - 1s 139ms/step - loss: 2.1465 - categorical_accuracy: 0.1532 - categorical_crossentropy: 2.0718
# 3/3 [==============================] - 0s 104ms/step

# %%
fig, axs = plt.subplots(ncols=3, sharex=True,figsize=(15,3))
axs[0].set_title("Most discriminative shapelet")
axs[0].plot(shp_clf.shapelets_[0],color="red",label="shapelet",lw=1)
axs[1].set_title("Second most discriminative shapelet")
axs[1].plot(shp_clf.shapelets_[1],color="green",label="shapelet",lw=1)
axs[2].set_title("third most discriminative shapelet")
axs[2].plot(shp_clf.shapelets_[2],color="blue",label="shapelet",lw=1)

# %%
print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.15384615384615385
# F1-score [0.         0.         0.         0.         0.26666667 0.
#  0.         0.        ]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        48
#            1       0.00      0.00      0.00        96
#            2       0.00      0.00      0.00        96
#            3       0.00      0.00      0.00        96
#            4       0.15      1.00      0.27        96
#            5       0.00      0.00      0.00        96
#            6       0.00      0.00      0.00        48
#            7       0.00      0.00      0.00        48
#
#     accuracy                           0.15       624
#    macro avg       0.02      0.12      0.03       624
# weighted avg       0.02      0.15      0.04       624

# %% [markdown]
# ## Shaplet-distances-based Classifier

# %%
X_train2 = shp_clf.transform(X_train)
X_test2 = shp_clf.transform(X_test)
# Out:
# 8/8 [==============================] - 1s 122ms/step
# 3/3 [==============================] - 0s 100ms/step

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors=8, weights='distance')
clf.fit(X_train2, y_train)
y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.21955128205128205
# F1-score [0.08888889 0.37837838 0.18536585 0.19047619 0.23469388 0.23036649
#  0.14634146 0.08219178]
#               precision    recall  f1-score   support
#
#            0       0.10      0.08      0.09        48
#            1       0.33      0.44      0.38        96
#            2       0.17      0.20      0.19        96
#            3       0.19      0.19      0.19        96
#            4       0.23      0.24      0.23        96
#            5       0.23      0.23      0.23        96
#            6       0.18      0.12      0.15        48
#            7       0.12      0.06      0.08        48
#
#     accuracy                           0.22       624
#    macro avg       0.19      0.20      0.19       624
# weighted avg       0.21      0.22      0.21       624

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(max_depth=8)
clf.fit(X_train2, y_train)

y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.2724358974358974
# F1-score [0.26966292 0.38613861 0.24074074 0.2994012  0.25984252 0.24516129
#  0.27272727 0.1038961 ]
#               precision    recall  f1-score   support
#
#            0       0.29      0.25      0.27        48
#            1       0.37      0.41      0.39        96
#            2       0.22      0.27      0.24        96
#            3       0.35      0.26      0.30        96
#            4       0.21      0.34      0.26        96
#            5       0.32      0.20      0.25        96
#            6       0.30      0.25      0.27        48
#            7       0.14      0.08      0.10        48
#
#     accuracy                           0.27       624
#    macro avg       0.27      0.26      0.26       624
# weighted avg       0.28      0.27      0.27       624

# %%
X_train2[0]
# Out:
# array([7.97220215e-04, 4.31962573e-04, 3.75437388e-08, 4.68216324e-03,
#        3.49803157e-02, 3.22048087e-03, 1.36856055e-02], dtype=float32)
